# %% [markdown]
# ## Kaggle Start Book in Python
#
# (PythonではじめるKaggleスタートブック)
#
# # section 2.8 Two heads are better than one!　Experience the ensemble!
#
# (2.8 三人寄れば文殊の知恵! アンサンブルを体験しよう)

# %% [markdown]
# original NoteBook :
#
# https://www.kaggle.com/code/sishihara/python-kaggle-start-book-ch02-08

# %%
ls ../input/submit-files
# Out:
# submission_lightgbm_holdout.csv  submission_randomforest.csv
# submission_lightgbm_skfold.csv

# %%
import pandas as pd


sub_lgbm_sk = pd.read_csv('../input/submit-files/submission_lightgbm_skfold.csv')
sub_lgbm_ho = pd.read_csv('../input/submit-files/submission_lightgbm_holdout.csv')
sub_rf = pd.read_csv('../input/submit-files/submission_randomforest.csv')

# %%
sub_lgbm_sk.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0

# %%
df = pd.DataFrame({'sub_lgbm_sk': sub_lgbm_sk['Survived'].values,
                                   'sub_lgbm_ho': sub_lgbm_ho['Survived'].values,
                                   'sub_rf': sub_rf['Survived'].values})
df.head()
# Out:
#    sub_lgbm_sk  sub_lgbm_ho  sub_rf
# 0            0            0       0
# 1            0            0       1
# 2            0            0       0
# 3            0            0       0
# 4            0            0       1

# %%
df.corr()
# Out:
#              sub_lgbm_sk  sub_lgbm_ho    sub_rf
# sub_lgbm_sk     1.000000     0.883077  0.796033
# sub_lgbm_ho     0.883077     1.000000  0.731329
# sub_rf          0.796033     0.731329  1.000000

# %% [markdown]
# * In ensemble learning, lower prediction correlation indicates better model diversity.
# * While there’s no strict threshold, a correlation of 0.95 or less is generally considered sufficiently low.

# %%
sub = pd.read_csv('../input/titanic/gender_submission.csv')
sub['Survived'] = sub_lgbm_sk['Survived'] + sub_lgbm_ho['Survived'] + sub_rf['Survived']
sub.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
sub['Survived'] = (sub['Survived'] >= 2).astype(int)
sub.to_csv('submission_lightgbm_ensemble.csv', index=False)
sub.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0

# %%
sub.to_csv('submission.csv', index=False)

# %% [markdown]
# Result :
#
# Your Best Entry!
# Your most recent submission scored 0.77033, which is an improvement of your previous score of 0.76794. Great job!
#
# Moved up to rank 10369 #kaggle https://kaggle.com/competitions/titanic

# %% [markdown]
# https://www.kaggle.com/code/yuki16/python-kaggle-start-book-ch02-08?scriptVersionId=241701427
